# %% [markdown]
# ## Sand Shear Stresses and Compactability
#
# ### Investigating sand shear strength in the swash zone and along the upper beach

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
root_path = '/Users/paulp/OneDrive - East Carolina University/Projects/USCRP_Pea_Island_2020_2021/'

data_path = '../Final_Data_Sets/'
data_file_name = 'PIBN_Bio_Env_NCDOT_CSI_2012-2020.csv'

plot_path = '../Final_Plots/'

# %%
def load_data(path, name):
    df_ = pd.read_csv(data_path+data_file_name)
    
    # create a new iso date time object field from existing sampling date:
    df_['iso_date'] = pd.to_datetime(df_['sample_date'])

    # to balance the design remove transects T-12 thru T-16 from the data:
    # we could have done this before the DOT to CSI label remapping but it would
    # have required additional code to detect the NT72,3,and 4 transects, too.
    df_.query("CSI_transect_ID != ['T12','T13','T14','T15','T16']", inplace=True)
    
    # create new survey field from existing sampling date:
    yr = df_['sample_date'].str[0:4]
    df_['year'] = yr
    mon = df_['sample_date'].str[5:7]
    df_['survey'] = mon+' '+yr
    
    # add shear strength aggregates for surface swash xone (0-3 inches) and mid-beach (average
    # over full 12 inches measured):
    
    df_['Shear_Strength_Swash'] = df_[['NCDOT_swc_0_3in','CSI_swc_1in']].mean(axis=1)
    df_['Shear_Strength_Midbeach'] = df_[['NCDOT_swc_0_3in','CSI_swc_6in',
                                             'NCDOT_swc_3_6in','CSI_swc_12in',
                                             'NCDOT_swc_6_9in','NCDOT_swc_9_12in']].mean(axis=1)
    # Finally, since winter doesn't present much bio data we will choose to drop all winter surveys:
    df_.query("season != ['winter']", inplace=True)
    
    # Finally, finally, drop a few more or less redundant surveys to reduce the 'noise' in the data:
    df_.query("survey != ['08 2015']", inplace=True)
    df_.query("survey != ['08 2016']", inplace=True)
    
    # integrity checks:
    print('Integrity checks:')
    print('Transect list:', df_['CSI_transect_ID'].unique())
    print('Areas:', df_['area'].unique())
    print('Epochs', df_['epoch'].unique())
    print(df_['season'].unique())
    
    return( df_ )

# %%
df = load_data(data_path, data_file_name)
df
# Out:
# Integrity checks:
# Transect list: ['C11' 'C09' 'C07' 'C05' 'C03' 'C01' 'T03' 'T05' 'T07' 'T09' 'T11' 'T01'
#  'T02' 'T04' 'T06' 'T08' 'T10' 'C02' 'C04' 'C06' 'C08' 'C10']
# Areas: ['Control' 'Treatment']
# Epochs ['prenourishment' 'postnourishment']
# ['spring' 'summer' 'autumn']
#      transect_id          sample_date  year  season CSI_transect_ID  \
# 0    apr2012_C11  2012/04/17 00:00:00  2012  spring             C11
# 1    apr2012_C09  2012/04/17 00:00:00  2012  spring             C09
# 2    apr2012_C07  2012/04/17 00:00:00  2012  spring             C07
# 3    apr2012_C05  2012/04/17 00:00:00  2012  spring             C05
# 4    apr2012_C03  2012/04/17 00:00:00  2012  spring             C03
# ..           ...                  ...   ...     ...             ...
# 852  oct2020_T07  2020/10/14 00:00:00  2020  autumn             T07
# 853  oct2020_T08  2020/10/14 00:00:00  2020  autumn             T08
# 854  oct2020_T09  2020/10/14 00:00:00  2020  autumn             T09
# 855  oct2020_T10  2020/10/14 00:00:00  2020  autumn             T10
# 856  oct2020_T11  2020/10/14 00:00:00  2020  autumn             T11
#
#     NCDOT_transect_ID data_origin       area            epoch  \
# 0                NT59       NCDOT    Control   prenourishment
# 1                NT60       NCDOT    Control   prenourishment
# 2                NT61       NCDOT    Control   prenourishment
# 3                NT62       NCDOT    Control   prenourishment
# 4                NT63       NCDOT    Control   prenourishment
# ..                ...         ...        ...              ...
# 852              NT69         CSI  Treatment  postnourishment
# 853               NaN         CSI  Treatment  postnourishment
# 854              NT70         CSI  Treatment  postnourishment
# 855               NaN         CSI  Treatment  postnourishment
# 856              NT71         CSI  Treatment  postnourishment
#
#                 epoch_II  ...  sm_Emerita  md_Emerita  lg_Emerita  Donax  \
# 0         prenourishment  ...         0.0         0.0         0.0    0.0
# 1         prenourishment  ...         0.0         0.0         0.0    0.0
# 2         prenourishment  ...         0.0         1.0         0.0    0.0
# 3         prenourishment  ...         0.0         2.0         0.0    0.0
# 4         prenourishment  ...         0.0         0.0         0.0    0.0
# ..                   ...  ...         ...         ...         ...    ...
# 852  postnourishment_6yr  ...         0.0         0.0         1.0    0.0
# 853  postnourishment_6yr  ...         0.0         0.0         0.0    0.0
# 854  postnourishment_6yr  ...         4.0         1.0         0.0    0.0
# 855  postnourishment_6yr  ...         2.0         0.0         0.0    0.0
# 856  postnourishment_6yr  ...         0.0         0.0         0.0    0.0
#
#      amphipods  worms   iso_date   survey  Shear_Strength_Swash  \
# 0          0.0    0.0 2012-04-17  04 2012                  80.0
# 1          0.0    0.0 2012-04-17  04 2012                 100.0
# 2          1.0    0.0 2012-04-17  04 2012                 140.0
# 3          0.0    0.0 2012-04-17  04 2012                 100.0
# 4          0.0    0.0 2012-04-17  04 2012                 100.0
# ..         ...    ...        ...      ...                   ...
# 852        0.0    0.0 2020-10-14  10 2020                  50.0
# 853        0.0    0.0 2020-10-14  10 2020                   0.0
# 854        0.0    0.0 2020-10-14  10 2020                   0.0
# 855        0.0    0.0 2020-10-14  10 2020                  24.9
# 856        0.0    0.0 2020-10-14  10 2020                   0.0
#
#      Shear_Strength_Midbeach
# 0                      195.0
# 1                      250.0
# 2                      245.0
# 3                      235.0
# 4                      225.0
# ..                       ...
# 852                    275.5
# 853                    200.0
# 854                    150.0
# 855                    275.5
# 856                    288.0
#
# [506 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 0 to 856
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   transect_id               506 non-null    object
#  1   sample_date               506 non-null    object
#  2   year                      506 non-null    object
#  3   season                    506 non-null    object
#  4   CSI_transect_ID           506 non-null    object
#  5   NCDOT_transect_ID         385 non-null    object
#  6   data_origin               506 non-null    object
#  7   area                      506 non-null    object
#  8   epoch                     506 non-null    object
#  9   epoch_II                  506 non-null    object
#  10  air_temp                  306 non-null    float64
#  11  water_temp                296 non-null    float64
#  12  wave_ht                   294 non-null    float64
#  13  salinity                  283 non-null    float64
#  14  swash_slope_deg           506 non-null    float64
#  15  NCDOT_swc_0_3in           264 non-null    float64
#  16  NCDOT_swc_3_6in           264 non-null    float64
#  17  NCDOT_swc_6_9in           264 non-null    float64
#  18  NCDOT_swc_9_12in          264 non-null    float64
#  19  Surface_Compaction_Swash  506 non-null    float64
#  20  CSI_swc_1in               242 non-null    float64
#  21  CSI_swc_6in               242 non-null    float64
#  22  CSI_swc_12in              241 non-null    float64
#  23  CSI_mbc_1in               153 non-null    float64
#  24  CSI_mbc_6in               153 non-null    float64
#  25  CSI_mbc_12in              153 non-null    float64
#  26  ghost_crabs               506 non-null    float64
#  27  sm_Emerita                506 non-null    float64
#  28  md_Emerita                506 non-null    float64
#  29  lg_Emerita                506 non-null    float64
#  30  Donax                     506 non-null    float64
#  31  amphipods                 506 non-null    float64
#  32  worms                     506 non-null    float64
#  33  iso_date                  506 non-null    datetime64[ns]
#  34  survey                    506 non-null    object
#  35  Shear_Strength_Swash      506 non-null    float64
#  36  Shear_Strength_Midbeach   506 non-null    float64
# dtypes: datetime64[ns](1), float64(25), object(11)
# memory usage: 150.2+ KB

# %%
g = sns.catplot(x='survey', y='Shear_Strength_Swash', hue='area', data=df, 
                kind='point',height=5, aspect=3.0, ci=95, capsize=0.1, legend=False)

g.set_axis_labels('', 'Shear Strength (psi)', size=18)
g.despine(left=True)
#g.set_yticklabels(['0','5','10','15','20','25','30'], size = 16)
#g.set_xticklabels('')
g.set_xticklabels(rotation=45, ha='right', fontsize=14)
    
plt.legend(loc='upper right', fontsize=21, frameon=False)
plt.title('Swash Zone (Mean over 0" -3" Depth)', fontsize=18, loc='center')
plt.tight_layout()

plt.savefig(plot_path+'Shear_Strength_swash_pointplot.pdf')
;
# Out:
# ''

# %%
g = sns.catplot(x='survey', y='Shear_Strength_Midbeach', hue='area', data=df, 
                kind='point',height=5, aspect=3.0, ci=95, capsize=0.1, legend=False)

g.set_axis_labels('', 'Shear Strength (psi)', size=18)
g.despine(left=True)
#g.set_yticklabels(['0','5','10','15','20','25','30'], size = 16)
#g.set_xticklabels('')
g.set_xticklabels(rotation=45, ha='right', fontsize=14)
    
plt.legend(loc='upper right', fontsize=21, frameon=False)
plt.title('Midbeach (Mean over 0" -12" Depth)', fontsize=18, loc='center')
plt.tight_layout()

plt.savefig(plot_path+'Shear_Strength_midbeach_pointplot.pdf')
;
# Out:
# ''

# %%
print( 'Avg. Shear - Swash (psi):', df['Shear_Strength_Swash'].loc[df['epoch'] == 'prenourishment'].mean() )
print( 'Avg. Shear - Midbeach (psi):', df['Shear_Strength_Midbeach'].loc[df['epoch'] == 'postnourishment'].mean())

print('')
print( 'Swash - Minimum Shear Stress Recorded Pre (psi):', df['Shear_Strength_Swash'].loc[df['epoch'] == 'prenourishment'].min() )
print( 'Swash - Maximum Shear Stress Recorded Pre (psi):', df['Shear_Strength_Swash'].loc[df['epoch'] == 'prenourishment'].max() )

print( 'Swash - Minimum Shear Stress Recorded Post (psi):', df['Shear_Strength_Swash'].loc[df['epoch'] == 'postnourishment'].min() )
print( 'Swash - Maximum Shear Stress Recorded Post (psi):', df['Shear_Strength_Swash'].loc[df['epoch'] == 'postnourishment'].max() )
print('')
print( 'Mid-Beach - Minimum Shear Stress Recorded Pre (psi):', df['Shear_Strength_Midbeach'].loc[df['epoch'] == 'prenourishment'].min() )
print( 'Mid-Beach - Maximum Shear Stress Recorded Pre (psi):', df['Shear_Strength_Midbeach'].loc[df['epoch'] == 'prenourishment'].max() )

print( 'Mid-Beach - Minimum Shear Stress Recorded Post (psi):', df['Shear_Strength_Midbeach'].loc[df['epoch'] == 'postnourishment'].min() )
print( 'Mid-Beach - Maximum Shear Stress Recorded Post (psi):', df['Shear_Strength_Midbeach'].loc[df['epoch'] == 'postnourishment'].max() )
# Out:
# Avg. Shear - Swash (psi): 62.31818181818182
# Avg. Shear - Midbeach (psi): 185.85820707070704
#
# Swash - Minimum Shear Stress Recorded Pre (psi): 5.0
# Swash - Maximum Shear Stress Recorded Pre (psi): 200.0
# Swash - Minimum Shear Stress Recorded Post (psi): 0.0
# Swash - Maximum Shear Stress Recorded Post (psi): 190.0
#
# Mid-Beach - Minimum Shear Stress Recorded Pre (psi): 33.75
# Mid-Beach - Maximum Shear Stress Recorded Pre (psi): 300.0
# Mid-Beach - Minimum Shear Stress Recorded Post (psi): 10.0
# Mid-Beach - Maximum Shear Stress Recorded Post (psi): 475.0

# %%
print( 'Swash Control - Minimum Shear Stress Recorded Pre (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'prenourishment') & (df['area'] == 'Control')].min() )
print( 'Swash Control - Maximum Shear Stress Recorded Pre (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'prenourishment') & (df['area'] == 'Control')].max() )
print('')
print( 'Swash Impact - Minimum Shear Stress Recorded Pre (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'prenourishment') & (df['area'] == 'Treatment')].min() )
print( 'Swash Impact - Maximum Shear Stress Recorded Pre (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'prenourishment') & (df['area'] == 'Treatment')].max() )
# Out:
# Swash Control - Minimum Shear Stress Recorded Pre (psi): 5.0
# Swash Control - Maximum Shear Stress Recorded Pre (psi): 200.0
#
# Swash Impact - Minimum Shear Stress Recorded Pre (psi): 10.0
# Swash Impact - Maximum Shear Stress Recorded Pre (psi): 180.0

# %%
print( 'Swash Control - Minimum Shear Stress Recorded Post (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'postnourishment') & (df['area'] == 'Control')].min() )
print( 'Swash Control - Maximum Shear Stress Recorded Post (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'postnourishment') & (df['area'] == 'Control')].max() )
print('')
print( 'Swash Impact - Minimum Shear Stress Recorded Post (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'postnourishment') & (df['area'] == 'Treatment')].min() )
print( 'Swash Impact - Maximum Shear Stress Recorded Post (psi):', \
      df['Shear_Strength_Swash'].loc[(df['epoch'] == 'postnourishment') & (df['area'] == 'Treatment')].max() )
# Out:
# Swash Control - Minimum Shear Stress Recorded Post (psi): 0.0
# Swash Control - Maximum Shear Stress Recorded Post (psi): 175.0
#
# Swash Impact - Minimum Shear Stress Recorded Post (psi): 0.0
# Swash Impact - Maximum Shear Stress Recorded Post (psi): 190.0
