# %% [markdown]
# ## Prep Dataframes

# %%
### ------------ Load data and package -----------------------------------------
### Load vegan package
library(vegan)
library(dplyr)
library(ggplot2)
library(vegan3d)

# %%
### Load and assemble the data
proj_path = '/Users/parisp15/OneDrive - East Carolina University/Projects/USCRP_Pea_Island_2020_2021/'
data_path = 'miscellaneous/Final Results Paper/Final_Data_Sets/'   #use_these_data_for_analysis/'
data_file_name = 'bio_data_2_R.csv'

# full_data_path = paste(proj_path, data_path, data_file_name, sep="")
df <- read.csv(file = paste(proj_path, data_path, data_file_name, sep=""))

## remove taxa recs where there are 0 counts for all swash species (bray distance
## measures don't work if you have all 0 abundance densities for one or more recs):
## NO NEED TO DO THIS IF you're using Euclidean distances...
df <- filter(df, O_quadrata != 0)


###  swash taxa df (E. talpoida, Donax spp., Amphipods, & Annelids):
# use square root to reduce influence of E. talpoida populations relative to others
taxa <- sqrt( df[c(8)] )

### spatio-temporal environment vars df (area, year, month, season, spoch):
taxa.env <- df[c(3,9:12)]

### ------------ COMPUTE DISTANCE MATRIX ---------------------------------------
taxa.dist <- vegdist(taxa, method='bray')

# %% [markdown]
# ## PerMANOVA

# %%
per_result <- adonis2(taxa.dist ~ epoch*area*season*month*year, data=taxa.env, permutations=999, method="bray")
per_result
# Out:
#                        Df SumOfSqs     R2            F          Pr(>F)
# epoch                   1  0.400347894  0.0299957433  7.4132206 0.001
# area                    1  0.045749058  0.0034277113  0.8471329 0.452
# season                  3  6.579877937  0.4929920506 40.6130830 0.001
# month                   1  0.088036940  0.0065960967  1.6301753 0.172
# year                    1  0.216636634  0.0162313252  4.0114490 0.014
# epoch:area              1 -0.011297839 -0.0008464815 -0.2092015 1.000
# epoch:season            3  0.443798197  0.0332512222  2.7392625 0.012
# area:season             3  0.272890061  0.0204460678  1.6843636 0.104
# area:month              1  0.064716336  0.0048488193  1.1983489 0.292
# season:month            3  0.370284709  0.0277432833  2.2855141 0.027
# epoch:year              1  0.139669065  0.0104645921  2.5862446 0.047
# area:year               1  0.032447033  0.0024310678  0.6008200 0.608
# season:year             3  0.370533838  0.0277619491  2.2870518 0.036
# month:year              1  0.122572671  0.0091836586  2.2696716 0.086
# epoch:area:season       3  0.074279681  0.0055653452  0.4584776 0.900
# area:season:month       3  0.487214427  0.0365041482  3.0072412 0.004
# epoch:area:year         1  0.003697818  0.0002770560  0.0684723 0.968
# epoch:season:year       3  0.657290737  0.0492469786  4.0570058 0.001
# area:season:year        3  0.096144114  0.0072035203  0.5934318 0.782
# area:month:year         1  0.012509151  0.0009372381  0.2316313 0.900
# season:month:year       2  0.548469430  0.0410936299  5.0779896 0.001
# epoch:area:season:year  3  0.192421760  0.0144170453  1.1876878 0.299
# area:season:month:year  1  0.032355179  0.0024241857  0.5991191 0.632
# Residual               39  2.106178772  0.1578037468         NA    NA
# Total                  83 13.346823602  1.0000000000         NA    NA

# %% [markdown]
# ## non-Metric Multi-Dimensional Scaling:

# %%
### ------------ NMDS ----------------------------------------------------------
### Run NMDS (default is bray)
nmds <- metaMDS(taxa, k=2, distance='bray', autotransform = FALSE)
nmds$stress
# Out:
# Run 0 stress 0.09520548
# Run 1 stress 0.1080944
# Run 2 stress 0.1184126
# Run 3 stress 0.1167008
# Run 4 stress 0.08420714
# ... New best solution
# ... Procrustes: rmse 0.06015718  max resid 0.5072574
# Run 5 stress 0.1055487
# Run 6 stress 0.1096458
# Run 7 stress 0.09382895
# Run 8 stress 0.1186054
# Run 9 stress 0.127958
# Run 10 stress 0.1217789
# Run 11 stress 0.1214791
# Run 12 stress 0.1046783
# Run 13 stress 0.08420715
# ... Procrustes: rmse 1.712499e-05  max resid 0.0001377814
# ... Similar to previous best
# Run 14 stress 0.08420714
# ... New best solution
# ... Procrustes: rmse 9.675211e-06  max resid 7.637022e-05
# ... Similar to previous best
# Run 15 stress 0.08420714
# ... Procrustes: rmse 1.216481e-05  max resid 0.0001000552
# ... Similar to previous best
# Run 16 stress 0.08420733
# ... Procrustes: rmse 9.724873e-05  max resid 0.0008370105
# ... Similar to previous best
# Run 17 stress 0.08420727
# ... Procrustes: rmse 8.578229e-05  max resid 0.0007416872
# ... Similar to previous best
# Run 18 stress 0.115708
# Run 19 stress 0.1085841
# Run 20 stress 0.08420715
# ... Procrustes: rmse 2.072555e-05  max resid 0.0001708106
# ... Similar to previous best
# *** Solution reached
# [1] 0.08420714

# %%
### --------PLOT NMDS PRE vs POST-----------------------------------------------
data_scores <- as.data.frame(scores(nmds))

scores <- cbind(as.data.frame(data_scores), Epoch = taxa.env$epoch)
centroids <- aggregate(cbind(NMDS1,NMDS2) ~ Epoch, data=scores, FUN=mean)
seg <- merge(scores, setNames(centroids, c('Epoch','NMDS1','NMDS2')),by='Epoch', sort=FALSE)

ggplot(scores, aes(x = NMDS1, y = NMDS2, colour = Epoch )) +
  geom_segment(aes(x=NMDS1.x, y=NMDS2.x, xend=NMDS1.y, yend=NMDS2.y), data=seg) +
  
  geom_point(data = centroids, size = 3) +                    # add centroids
  geom_point(size=1) +                                              
  coord_fixed()+                                              
  theme_bw()+ 
  theme(legend.position="right",legend.text=element_text(size=10),legend.direction='vertical')
# Out:
# plot without title

# %% [markdown]
# ## Beta Dispersion & Dispersion Test for Homogeneity of Variance

# %%
# time:
bdt <- betadisper(taxa.dist, taxa.env$epoch)    # computes PCoA result!
boxplot(bdt)
anova(bdt)   # F-Test
permutest(bdt) # permutation test   (not significant means pre and post dispersion is alike)
# Out:
#           Df Sum Sq      Mean Sq     F value  Pr(>F)
# Groups     1 0.003979779 0.003979779 0.165851 0.684887
# Residuals 82 1.967681579 0.023996117       NA       NA
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df  Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.00398 0.0039798 0.1659    999  0.679
# Residuals 82 1.96768 0.0239961
# plot without title

# %%
# space:
bds <- betadisper(taxa.dist, taxa.env$area)    # computes PCoA result!
boxplot(bds)
anova(bds)   # F-Test
permutest(bds) # permutation test   (not significant means pre and post dispersion is alike)
# Out:
#           Df Sum Sq      Mean Sq     F value    Pr(>F)
# Groups     1 0.002015314 0.002015314 0.09849965 0.7544346
# Residuals 82 1.677729676 0.020460118         NA        NA
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df  Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.00202 0.0020153 0.0985    999  0.742
# Residuals 82 1.67773 0.0204601
# plot without title
